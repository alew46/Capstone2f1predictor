# %% [markdown]
# ## Intro
#
# This notebook contains basic importing and light formatting of data to support my F1 Predictor project. The data below is queried from the [Egrast API](http://ergast.com/mrd/).
#
# The Ergast database contains information on races, drivers, qualifying and final grand prox results, and more going back to the 1950s. Some features have more historical data than others for a variety of reasons. For example, though the first F1 World Championship was in 1950, the first Constructor's Champion wasn't crowned until 1958.
#
# Importantly, Ergast rate-limits the API calls you can make. You must specify the number of rows to be returned with a limit of 1000. You can also offset the starting point of those rows via query string. In my project, I'm interested in making predictions about current F1 drivers and teams - so I attach query strings to fetch the most recent race data, going back to 2008.
#
# ### Races
#
# The first table to import is Ergast's base list of races (aka, Grand Prix events) per season. This is the top-most level of Ergast's database, "Race Schedule".

# %%
# import the basic packages, including requests to handle API calls and results
import pandas as pd
import numpy as np
import requests
import json

# %%
# fetch the database from Ergast as JSON
# turn json response into a DataFrame

    # this was my attempt at using a loop to move through the json returned by the API 1000 rows at a time. 

            # limit = 1000
            # offset = [0, 1000, 2000]

            # race_dict = {}

            # for interval in offset:
            #     url = f'http://ergast.com/api/f1.json?limit={limit}&offset={offset}'
            #     res = requests.get(url)
            #     json = res.json()

            #     race_dict.update(json)
    
    # I couldn't get that to work, so instead I went the long way by creating two separate dictionaries with two
    # separate API calls, then merging them together.

race_1 = {}

url = f'http://ergast.com/api/f1.json?limit=1000&offset=0'
res = requests.get(url)
json = res.json()
    
race_1.update(json)

df_race_1 = pd.DataFrame.from_dict(race_1['MRData']['RaceTable']['Races'], orient="columns")
df_race_1
# Out:
#     season round                                                url  \
# 0     1950     1  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1     1950     2  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 2     1950     3  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 3     1950     4  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 4     1950     5  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# ..     ...   ...                                                ...
# 995   2018    20  https://en.wikipedia.org/wiki/2018_Brazilian_G...
# 996   2018    21  https://en.wikipedia.org/wiki/2018_Abu_Dhabi_G...
# 997   2019     1  https://en.wikipedia.org/wiki/2019_Australian_...
# 998   2019     2  https://en.wikipedia.org/wiki/2019_Bahrain_Gra...
# 999   2019     3  https://en.wikipedia.org/wiki/2019_Chinese_Gra...
#
#                   raceName                                            Circuit  \
# 0       British Grand Prix  {'circuitId': 'silverstone', 'url': 'http://en...
# 1        Monaco Grand Prix  {'circuitId': 'monaco', 'url': 'http://en.wiki...
# 2         Indianapolis 500  {'circuitId': 'indianapolis', 'url': 'http://e...
# 3         Swiss Grand Prix  {'circuitId': 'bremgarten', 'url': 'http://en....
# 4       Belgian Grand Prix  {'circuitId': 'spa', 'url': 'http://en.wikiped...
# ..                     ...                                                ...
# 995   Brazilian Grand Prix  {'circuitId': 'interlagos', 'url': 'http://en....
# 996   Abu Dhabi Grand Prix  {'circuitId': 'yas_marina', 'url': 'http://en....
# 997  Australian Grand Prix  {'circuitId': 'albert_park', 'url': 'http://en...
# 998     Bahrain Grand Prix  {'circuitId': 'bahrain', 'url': 'http://en.wik...
# 999     Chinese Grand Prix  {'circuitId': 'shanghai', 'url': 'http://en.wi...
#
#            date       time
# 0    1950-05-13        NaN
# 1    1950-05-21        NaN
# 2    1950-05-30        NaN
# 3    1950-06-04        NaN
# 4    1950-06-18        NaN
# ..          ...        ...
# 995  2018-11-11  17:10:00Z
# 996  2018-11-25  13:10:00Z
# 997  2019-03-17  05:10:00Z
# 998  2019-03-31  15:10:00Z
# 999  2019-04-14  06:10:00Z
#
# [1000 rows x 7 columns]

# %%
race_2 = {}

url = f'http://ergast.com/api/f1.json?limit=1000&offset=1000'
res = requests.get(url)
json = res.json()
    
race_2.update(json)

df_race_2 = pd.DataFrame.from_dict(race_2['MRData']['RaceTable']['Races'], orient="columns")
df_race_2
# Out:
#    season round                                                url  \
# 0    2019     4  https://en.wikipedia.org/wiki/2019_Azerbaijan_...
# 1    2019     5  https://en.wikipedia.org/wiki/2019_Spanish_Gra...
# 2    2019     6  https://en.wikipedia.org/wiki/2019_Monaco_Gran...
# 3    2019     7  https://en.wikipedia.org/wiki/2019_Canadian_Gr...
# 4    2019     8  https://en.wikipedia.org/wiki/2019_French_Gran...
# ..    ...   ...                                                ...
# 75   2022    19  https://en.wikipedia.org/wiki/2022_Japanese_Gr...
# 76   2022    20  https://en.wikipedia.org/wiki/2022_United_Stat...
# 77   2022    21  https://en.wikipedia.org/wiki/2022_Mexican_Gra...
# 78   2022    22  https://en.wikipedia.org/wiki/2022_S%C3%A3o_Pa...
# 79   2022    23  https://en.wikipedia.org/wiki/2022_Abu_Dhabi_G...
#
#                     raceName  \
# 0      Azerbaijan Grand Prix
# 1         Spanish Grand Prix
# 2          Monaco Grand Prix
# 3        Canadian Grand Prix
# 4          French Grand Prix
# ..                       ...
# 75       Japanese Grand Prix
# 76  United States Grand Prix
# 77    Mexico City Grand Prix
# 78      São Paulo Grand Prix
# 79      Abu Dhabi Grand Prix
#
#                                               Circuit        date       time
# 0   {'circuitId': 'BAK', 'url': 'http://en.wikiped...  2019-04-28  12:10:00Z
# 1   {'circuitId': 'catalunya', 'url': 'http://en.w...  2019-05-12  13:10:00Z
# 2   {'circuitId': 'monaco', 'url': 'http://en.wiki...  2019-05-26  13:10:00Z
# 3   {'circuitId': 'villeneuve', 'url': 'http://en....  2019-06-09  18:10:00Z
# 4   {'circuitId': 'ricard', 'url': 'http://en.wiki...  2019-06-23  13:10:00Z
# ..                                                ...         ...        ...
# 75  {'circuitId': 'suzuka', 'url': 'http://en.wiki...  2022-10-09  05:10:00Z
# 76  {'circuitId': 'americas', 'url': 'http://en.wi...  2022-10-23  19:00:00Z
# 77  {'circuitId': 'rodriguez', 'url': 'http://en.w...  2022-10-30  19:00:00Z
# 78  {'circuitId': 'interlagos', 'url': 'http://en....  2022-11-13  17:00:00Z
# 79  {'circuitId': 'yas_marina', 'url': 'http://en....  2022-11-20  13:00:00Z
#
# [80 rows x 7 columns]

# %%
df_races = pd.concat([df_race_1, df_race_2])
df_races
# Out:
#    season round                                                url  \
# 0    1950     1  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1    1950     2  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 2    1950     3  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 3    1950     4  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 4    1950     5  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# ..    ...   ...                                                ...
# 75   2022    19  https://en.wikipedia.org/wiki/2022_Japanese_Gr...
# 76   2022    20  https://en.wikipedia.org/wiki/2022_United_Stat...
# 77   2022    21  https://en.wikipedia.org/wiki/2022_Mexican_Gra...
# 78   2022    22  https://en.wikipedia.org/wiki/2022_S%C3%A3o_Pa...
# 79   2022    23  https://en.wikipedia.org/wiki/2022_Abu_Dhabi_G...
#
#                     raceName  \
# 0         British Grand Prix
# 1          Monaco Grand Prix
# 2           Indianapolis 500
# 3           Swiss Grand Prix
# 4         Belgian Grand Prix
# ..                       ...
# 75       Japanese Grand Prix
# 76  United States Grand Prix
# 77    Mexico City Grand Prix
# 78      São Paulo Grand Prix
# 79      Abu Dhabi Grand Prix
#
#                                               Circuit        date       time
# 0   {'circuitId': 'silverstone', 'url': 'http://en...  1950-05-13        NaN
# 1   {'circuitId': 'monaco', 'url': 'http://en.wiki...  1950-05-21        NaN
# 2   {'circuitId': 'indianapolis', 'url': 'http://e...  1950-05-30        NaN
# 3   {'circuitId': 'bremgarten', 'url': 'http://en....  1950-06-04        NaN
# 4   {'circuitId': 'spa', 'url': 'http://en.wikiped...  1950-06-18        NaN
# ..                                                ...         ...        ...
# 75  {'circuitId': 'suzuka', 'url': 'http://en.wiki...  2022-10-09  05:10:00Z
# 76  {'circuitId': 'americas', 'url': 'http://en.wi...  2022-10-23  19:00:00Z
# 77  {'circuitId': 'rodriguez', 'url': 'http://en.w...  2022-10-30  19:00:00Z
# 78  {'circuitId': 'interlagos', 'url': 'http://en....  2022-11-13  17:00:00Z
# 79  {'circuitId': 'yas_marina', 'url': 'http://en....  2022-11-20  13:00:00Z
#
# [1080 rows x 7 columns]

# %%
# Before I leave this DataFrame, I extract the circuitName (which in F1 terms is often but not always synonomous with 
# the raceName. For example, the United States Grand Prix has been held at six different circuits over the years.)

df_races['circuitName'] = df_races['Circuit'].apply(lambda k: k['circuitId'] )
df_races
# Out:
#    season round                                                url  \
# 0    1950     1  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1    1950     2  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 2    1950     3  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 3    1950     4  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 4    1950     5  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# ..    ...   ...                                                ...
# 75   2022    19  https://en.wikipedia.org/wiki/2022_Japanese_Gr...
# 76   2022    20  https://en.wikipedia.org/wiki/2022_United_Stat...
# 77   2022    21  https://en.wikipedia.org/wiki/2022_Mexican_Gra...
# 78   2022    22  https://en.wikipedia.org/wiki/2022_S%C3%A3o_Pa...
# 79   2022    23  https://en.wikipedia.org/wiki/2022_Abu_Dhabi_G...
#
#                     raceName  \
# 0         British Grand Prix
# 1          Monaco Grand Prix
# 2           Indianapolis 500
# 3           Swiss Grand Prix
# 4         Belgian Grand Prix
# ..                       ...
# 75       Japanese Grand Prix
# 76  United States Grand Prix
# 77    Mexico City Grand Prix
# 78      São Paulo Grand Prix
# 79      Abu Dhabi Grand Prix
#
#                                               Circuit        date       time  \
# 0   {'circuitId': 'silverstone', 'url': 'http://en...  1950-05-13        NaN
# 1   {'circuitId': 'monaco', 'url': 'http://en.wiki...  1950-05-21        NaN
# 2   {'circuitId': 'indianapolis', 'url': 'http://e...  1950-05-30        NaN
# 3   {'circuitId': 'bremgarten', 'url': 'http://en....  1950-06-04        NaN
# 4   {'circuitId': 'spa', 'url': 'http://en.wikiped...  1950-06-18        NaN
# ..                                                ...         ...        ...
# 75  {'circuitId': 'suzuka', 'url': 'http://en.wiki...  2022-10-09  05:10:00Z
# 76  {'circuitId': 'americas', 'url': 'http://en.wi...  2022-10-23  19:00:00Z
# 77  {'circuitId': 'rodriguez', 'url': 'http://en.w...  2022-10-30  19:00:00Z
# 78  {'circuitId': 'interlagos', 'url': 'http://en....  2022-11-13  17:00:00Z
# 79  {'circuitId': 'yas_marina', 'url': 'http://en....  2022-11-20  13:00:00Z
#
#      circuitName
# 0    silverstone
# 1         monaco
# 2   indianapolis
# 3     bremgarten
# 4            spa
# ..           ...
# 75        suzuka
# 76      americas
# 77     rodriguez
# 78    interlagos
# 79    yas_marina
#
# [1080 rows x 8 columns]

# %% [markdown]
# ### Results
#
# The results of a race include the grid position of each driver (a grid position of 1 indicates the winner) as well as important race data including each driver's fastest lap time, average lap time, and whether or not they successfully completed the course.

# %%
url = 'http://ergast.com/api/f1/results.json?limit=500&offset=800'
res = requests.get(url)
json = res.json()

# %%
df_results = pd.DataFrame.from_dict(json['MRData']['RaceTable']['Races'][0]['Results'], orient="columns")
df_results
# Out:
#    number position positionText points  \
# 0       2        1            1      8
# 1      10        2            2      6
# 2      12        3            3      5
# 3      26        4            4      3
# 4      20        5            5      2
# 5      28        6            6      0
# 6       8        7            7      0
# 7      30        8            8      0
# 8      16        9            9      0
# 9      18       10            D      0
# 10     14       11            D      0
# 11      4       12            R      0
# 12     32       13            R      0
# 13     22       14            R      0
# 14     34       15            R      0
# 15     24       16            R      0
# 16      6       17            W      0
# 17     36       18            W      0
#
#                                                Driver  \
# 0   {'driverId': 'fangio', 'url': 'http://en.wikip...
# 1   {'driverId': 'farina', 'url': 'http://en.wikip...
# 2   {'driverId': 'gonzalez', 'url': 'http://en.wik...
# 3   {'driverId': 'trintignant', 'url': 'http://en....
# 4   {'driverId': 'bayol', 'url': 'http://en.wikipe...
# 5   {'driverId': 'schell', 'url': 'http://en.wikip...
# 6   {'driverId': 'bira', 'url': 'http://en.wikiped...
# 7   {'driverId': 'graffenried', 'url': 'http://en....
# 8   {'driverId': 'maglioli', 'url': 'http://en.wik...
# 9   {'driverId': 'behra', 'url': 'http://en.wikipe...
# 10  {'driverId': 'hawthorn', 'url': 'http://en.wik...
# 11  {'driverId': 'marimon', 'url': 'http://en.wiki...
# 12  {'driverId': 'mieres', 'url': 'http://en.wikip...
# 13  {'driverId': 'loyer', 'url': 'http://en.wikipe...
# 14  {'driverId': 'daponte', 'url': 'http://en.wiki...
# 15  {'driverId': 'rosier', 'url': 'http://en.wikip...
# 16  {'driverId': 'musso', 'url': 'http://en.wikipe...
# 17  {'driverId': 'menditeguy', 'url': 'http://en.w...
#
#                                           Constructor grid laps        status  \
# 0   {'constructorId': 'maserati', 'url': 'http://e...    3   87      Finished
# 1   {'constructorId': 'ferrari', 'url': 'http://en...    1   87      Finished
# 2   {'constructorId': 'ferrari', 'url': 'http://en...    2   87      Finished
# 3   {'constructorId': 'ferrari', 'url': 'http://en...    5   86        +1 Lap
# 4   {'constructorId': 'gordini', 'url': 'http://en...   15   85       +2 Laps
# 5   {'constructorId': 'maserati', 'url': 'http://e...   11   84       +3 Laps
# 6   {'constructorId': 'maserati', 'url': 'http://e...   10   83       +4 Laps
# 7   {'constructorId': 'maserati', 'url': 'http://e...   13   83       +4 Laps
# 8   {'constructorId': 'ferrari', 'url': 'http://en...   12   82       +5 Laps
# 9   {'constructorId': 'gordini', 'url': 'http://en...   17   61  Disqualified
# 10  {'constructorId': 'ferrari', 'url': 'http://en...    4   52  Disqualified
# 11  {'constructorId': 'maserati', 'url': 'http://e...    6   48        Engine
# 12  {'constructorId': 'maserati', 'url': 'http://e...    8   37      Oil leak
# 13  {'constructorId': 'gordini', 'url': 'http://en...   16   19  Oil pressure
# 14  {'constructorId': 'maserati', 'url': 'http://e...   18   19       Gearbox
# 15  {'constructorId': 'ferrari', 'url': 'http://en...   14    1      Accident
# 16  {'constructorId': 'maserati', 'url': 'http://e...    7    0      Withdrew
# 17  {'constructorId': 'maserati', 'url': 'http://e...    9    0      Withdrew
#
#                                            Time
# 0   {'millis': '10855800', 'time': '3:00:55.8'}
# 1     {'millis': '10934800', 'time': '+1:19.0'}
# 2     {'millis': '10976800', 'time': '+2:01.0'}
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN

# %%
for i in json.keys():
    print(i)
    for j in json[i].keys():
        print(j)
# Out:
# MRData
# xmlns
# series
# url
# limit
# offset
# total
# RaceTable

# %%
df_results['DriverLastName'] = df_results['Driver'].apply(lambda k: k['familyName'] )

# %%
df_results
# Out:
#    number position positionText points  \
# 0       2        1            1      8
# 1      10        2            2      6
# 2      12        3            3      5
# 3      26        4            4      3
# 4      20        5            5      2
# 5      28        6            6      0
# 6       8        7            7      0
# 7      30        8            8      0
# 8      16        9            9      0
# 9      18       10            D      0
# 10     14       11            D      0
# 11      4       12            R      0
# 12     32       13            R      0
# 13     22       14            R      0
# 14     34       15            R      0
# 15     24       16            R      0
# 16      6       17            W      0
# 17     36       18            W      0
#
#                                                Driver  \
# 0   {'driverId': 'fangio', 'url': 'http://en.wikip...
# 1   {'driverId': 'farina', 'url': 'http://en.wikip...
# 2   {'driverId': 'gonzalez', 'url': 'http://en.wik...
# 3   {'driverId': 'trintignant', 'url': 'http://en....
# 4   {'driverId': 'bayol', 'url': 'http://en.wikipe...
# 5   {'driverId': 'schell', 'url': 'http://en.wikip...
# 6   {'driverId': 'bira', 'url': 'http://en.wikiped...
# 7   {'driverId': 'graffenried', 'url': 'http://en....
# 8   {'driverId': 'maglioli', 'url': 'http://en.wik...
# 9   {'driverId': 'behra', 'url': 'http://en.wikipe...
# 10  {'driverId': 'hawthorn', 'url': 'http://en.wik...
# 11  {'driverId': 'marimon', 'url': 'http://en.wiki...
# 12  {'driverId': 'mieres', 'url': 'http://en.wikip...
# 13  {'driverId': 'loyer', 'url': 'http://en.wikipe...
# 14  {'driverId': 'daponte', 'url': 'http://en.wiki...
# 15  {'driverId': 'rosier', 'url': 'http://en.wikip...
# 16  {'driverId': 'musso', 'url': 'http://en.wikipe...
# 17  {'driverId': 'menditeguy', 'url': 'http://en.w...
#
#                                           Constructor grid laps        status  \
# 0   {'constructorId': 'maserati', 'url': 'http://e...    3   87      Finished
# 1   {'constructorId': 'ferrari', 'url': 'http://en...    1   87      Finished
# 2   {'constructorId': 'ferrari', 'url': 'http://en...    2   87      Finished
# 3   {'constructorId': 'ferrari', 'url': 'http://en...    5   86        +1 Lap
# 4   {'constructorId': 'gordini', 'url': 'http://en...   15   85       +2 Laps
# 5   {'constructorId': 'maserati', 'url': 'http://e...   11   84       +3 Laps
# 6   {'constructorId': 'maserati', 'url': 'http://e...   10   83       +4 Laps
# 7   {'constructorId': 'maserati', 'url': 'http://e...   13   83       +4 Laps
# 8   {'constructorId': 'ferrari', 'url': 'http://en...   12   82       +5 Laps
# 9   {'constructorId': 'gordini', 'url': 'http://en...   17   61  Disqualified
# 10  {'constructorId': 'ferrari', 'url': 'http://en...    4   52  Disqualified
# 11  {'constructorId': 'maserati', 'url': 'http://e...    6   48        Engine
# 12  {'constructorId': 'maserati', 'url': 'http://e...    8   37      Oil leak
# 13  {'constructorId': 'gordini', 'url': 'http://en...   16   19  Oil pressure
# 14  {'constructorId': 'maserati', 'url': 'http://e...   18   19       Gearbox
# 15  {'constructorId': 'ferrari', 'url': 'http://en...   14    1      Accident
# 16  {'constructorId': 'maserati', 'url': 'http://e...    7    0      Withdrew
# 17  {'constructorId': 'maserati', 'url': 'http://e...    9    0      Withdrew
#
#                                            Time  DriverLastName
# 0   {'millis': '10855800', 'time': '3:00:55.8'}          Fangio
# 1     {'millis': '10934800', 'time': '+1:19.0'}          Farina
# 2     {'millis': '10976800', 'time': '+2:01.0'}        González
# 3                                           NaN     Trintignant
# 4                                           NaN           Bayol
# 5                                           NaN          Schell
# 6                                           NaN            Bira
# 7                                           NaN  de Graffenried
# 8                                           NaN        Maglioli
# 9                                           NaN           Behra
# 10                                          NaN        Hawthorn
# 11                                          NaN         Marimón
# 12                                          NaN          Mieres
# 13                                          NaN           Loyer
# 14                                          NaN         Daponte
# 15                                          NaN          Rosier
# 16                                          NaN           Musso
# 17                                          NaN      Menditeguy
